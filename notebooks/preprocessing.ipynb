# %%
import os

os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/data", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/notebooks", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/src", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/results", exist_ok=True)

# %%
# %%writefile /content/drive/MyDrive/UNet-LIDC-Segmentation/notebooks/preprocessing.ipynb
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Preprocessing & PyLIDC Consensus Mask Generation\n",
#     "This notebook loads LIDC-IDRI DICOMs using PyLIDC and exports:\n",
#     "- `X_train.npy`, `Y_train.npy`\n",
#     "- `X_val.npy`, `Y_val.npy`"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "source": [
#     "import os\n",
#     "import pylidc as pl\n",
#     "import numpy as np\n",
#     "from tqdm import tqdm\n",
#     "import matplotlib.pyplot as plt"
#    ],
#    "execution_count": null,
#    "outputs": []
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "source": [
#     "# Path to your LIDC-IDRI root folder (update if needed)\n",
#     "LIDC_PATH = '/content/drive/MyDrive/UNet-LIDC-Segmentation/data/LIDC-IDRI'"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "source": [
#     "scans = pl.query(pl.Scan).all()\n",
#     "len(scans)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "source": [
#     "images = []\n",
#     "masks = []\n",
#     "\n",
#     "for scan in tqdm(scans):\n",
#     "    anns = scan.cluster_annotations()\n",
#     "    for cluster in anns:\n",
#     "        cmask, cbbox, masks_list = scan.combine_masks(cluster)\n",
#     "        img = scan.to_volume()\n",
#     "        x0,x1,y0,y1,z0,z1 = cbbox\n",
#     "        patch = img[z0:z1, y0:y1, x0:x1]\n",
#     "        images.append(patch)\n",
#     "        masks.append(cmask)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "source": [
#     "images = np.array(images)\n",
#     "masks = np.array(masks)\n",
#     "images.shape, masks.shape"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "metadata": {},
#    "source": [
#     "np.save('/content/drive/MyDrive/UNet-LIDC-Segmentation/data/X.npy', images)\n",
#     "np.save('/content/drive/MyDrive/UNet-LIDC-Segmentation/data/Y.npy', masks)"
#    ]
#   }
#  ],
#  "metadata": {
#   "colab": {},
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 0
# }
# Out:
# Writing /content/drive/MyDrive/UNet-LIDC-Segmentation/notebooks/preprocessing.ipynb
