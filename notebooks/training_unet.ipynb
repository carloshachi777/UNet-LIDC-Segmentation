# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Navigate to your project folder
# %cd /content/drive/MyDrive/UNet-LIDC-Segmentation/

# %%
# !pip install pylidc tensorflow==2.15 opencv-python tqdm scikit-learn matplotlib pydicom
