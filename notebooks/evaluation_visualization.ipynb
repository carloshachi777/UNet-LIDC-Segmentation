# %%
import os

os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/data", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/notebooks", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/src", exist_ok=True)
os.makedirs("/content/drive/MyDrive/UNet-LIDC-Segmentation/results", exist_ok=True)

# %%
# %%writefile /content/drive/MyDrive/UNet-LIDC-Segmentation/notebooks/evaluation_visualization.ipynb
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "source": [
#     "# Evaluation & Visualization Notebook\n",
#     "This notebook loads the trained U-Net model and visualizes predictions."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "source": [
#     "import numpy as np\n",
#     "import matplotlib.pyplot as plt\n",
#     "from tensorflow.keras.models import load_model"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "source": [
#     "model = load_model('/content/drive/MyDrive/UNet-LIDC-Segmentation/results/unet_model.h5', compile=False)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "source": [
#     "X_val = np.load('/content/drive/MyDrive/UNet-LIDC-Segmentation/data/X_val.npy')\n",
#     "Y_val = np.load('/content/drive/MyDrive/UNet-LIDC-Segmentation/data/Y_val.npy')"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "source": [
#     "pred = model.predict(X_val[:10])"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "source": [
#     "fig, axes = plt.subplots(10, 3, figsize=(12, 30))\n",
#     "for i in range(10):\n",
#     "    axes[i,0].imshow(X_val[i], cmap='gray')\n",
#     "    axes[i,0].set_title('Input')\n",
#     "    axes[i,1].imshow(Y_val[i], cmap='gray')\n",
#     "    axes[i,1].set_title('Ground Truth')\n",
#     "    axes[i,2].imshow(pred[i] > 0.5, cmap='gray')\n",
#     "    axes[i,2].set_title('Prediction')\n",
#     "plt.tight_layout()"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 0
# }
# Out:
# Writing /content/drive/MyDrive/UNet-LIDC-Segmentation/notebooks/evaluation_visualization.ipynb
